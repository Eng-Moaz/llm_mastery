# %%
from engine import Value
from visualizer import draw_dot

# %%
a = Value(4.0, label="a")
b = Value(3.0, label="b")
c = a / b
c.label = "c"

# %%
c.backward()
c
# Out:
# Value is 1.3333333333333333

# %%
c._prev
# Out:
# {Value is 0.3333333333333333, Value is 4.0}

# %%
draw_dot(c)
